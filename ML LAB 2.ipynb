# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

thyro=pd.read_excel(r'C:\Users\hemanth\Downloads\19CSE305_LabData_Set3.1.xlsx', sheet_name="thyroid0387_UCI", na_values = "not available")

thyro
# Out:
#      Record ID  age sex on thyroxine query on thyroxine  \
# 0    840801013   29   F            f                  f
# 1    840801014   29   F            f                  f
# 2    840801042   41   F            f                  f
# 3    840803046   36   F            f                  f
# 4    840803047   32   F            f                  f
# ..         ...  ...  ..          ...                ...
# 995  841031002   41   F            f                  f
# 996  841031010   41   F            f                  f
# 997  841031030   20   F            f                  f
# 998  841031031   20   F            f                  f
# 999  841031032   73   F            f                  f
#
#     on antithyroid medication sick pregnant thyroid surgery I131 treatment  \
# 0                           f    f        f               f              f
# 1                           f    f        f               f              f
# ...

# %%
Agemean = thyro['age'].mean()
Agevar = thyro['age'].var()
print(Agemean)
print(Agevar)
# Out:
# 51.509
# 352.5584774774786

# %%
types = thyro.dtypes

print(types)
# Out:
# Record ID                     int64
# age                           int64
# sex                          object
# on thyroxine                 object
# query on thyroxine           object
# on antithyroid medication    object
# sick                         object
# pregnant                     object
# thyroid surgery              object
# I131 treatment               object
# query hypothyroid            object
# query hyperthyroid           object
# lithium                      object
# goitre                       object
# tumor                        object
# hypopituitary                object
# psych                        object
# TSH measured                 object
# TSH                          object
# T3 measured                  object
# T3                           object
# TT4 measured                 object
# TT4                          object
# T4U measured                 object
# T4U                          object
# FTI measured                 object
# ...

# %%
thyro['age'].value_counts()
# Out:
# 55    36
# 72    36
# 62    31
# 41    27
# 58    26
#       ..
# 1      1
# 2      1
# 97     1
# 6      1
# 89     1
# Name: age, Length: 87, dtype: int64

# %%
thyro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record ID                  1000 non-null   int64
#  1   age                        1000 non-null   int64
#  2   sex                        1000 non-null   object
#  3   on thyroxine               1000 non-null   object
#  4   query on thyroxine         1000 non-null   object
#  5   on antithyroid medication  1000 non-null   object
#  6   sick                       1000 non-null   object
#  7   pregnant                   1000 non-null   object
#  8   thyroid surgery            1000 non-null   object
#  9   I131 treatment             1000 non-null   object
#  10  query hypothyroid          1000 non-null   object
#  11  query hyperthyroid         1000 non-null   object
#  12  lithium                    1000 non-null   object
# ...

# %%
thyro.describe()
# Out:
#           Record ID          age
# count  1.000000e+03  1000.000000
# mean   8.409340e+08    51.509000
# std    7.628734e+04    18.776541
# min    8.408010e+08     1.000000
# 25%    8.409031e+08    35.000000
# 50%    8.409210e+08    55.000000
# 75%    8.410111e+08    67.000000
# max    8.410310e+08    97.000000

# %%
print((thyro["TSH"].unique()))
print("--"*50)
print((thyro["T3"].unique()))
# Out:
# [0.3 1.6 '?' 0.7 1.2 1.9 1 0.5 2.6 68 1.5 5.9 0.05 4 0.4 0.8 0.2 3
#  9.599999 140 0.6 1.7 2.5 6.8 2.1 1.1 9.799999 3.7 0.1 0.35 90 1.3 2.7 2.9
#  0.25 5.8 2 0.9 3.2 7.4 1.8 5 70 6.5 11.599999 4.2 88 2.2 53 16.5 8.4 4.1
#  3.3 80 176 30 11 6 71 9.099999 10.7 4.9 3.4 1.83 4.6 1.4 14 3.5 46 18 170
#  19.199999 7.5 145 7.9 19 48 25 7.3 6.7 153 35 3.8 2.3 9.2 12 5.5
#  15.299999 0.15 10.299999 430 213 37 216 26 4.3 2.4 47 8.2 14.4 17.4 100
#  13.2 41 3.1 22 45 4.5 24 65 4.4 56 11.4 5.2 5.6 8.299999 400 260 5.4 8
#  6.6 8.5 5.1 138 42 44 2.8 10 54 3.9 150]
# ----------------------------------------------------------------------------------------------------
# ['?' 1.9 2.6 1.8 1.7 2.3 2.4 2.9 2 2.1 1.6 0.1 1.4 1.2 1.5 1.3 2.5 2.7 2.2
#  2.8 3.2 0.4 0.8 1 1.1 3.7 4.4 3 3.1 3.6 7.6 0.9 4.2 0.5 0.6 0.3 0.7 3.8
#  0.2 4.1 6.6 4.7 8.599999 3.3 4.3 0.05 3.4]

# %%
print((thyro["FTI"].unique()))
print("--"*50)
print((thyro["TT4"].unique()))

print((thyro["T4U"].unique()))
print("--"*50)
print((thyro["FTI"].unique()))
print()
print((thyro["TBG"].unique()))
print("--"*50)
# Out:
# ['?' 47 85 84 96 105 95 106 176 129 100 69 39 91 90 93 66 121 92 173 117
#  31 113 67 101 126 123 149 68 86 132 131 116 97 124 136 142 104 7.5 107 73
#  110 130 88 128 122 102 134 163 63 354 81 109 114 133 170 99 111 108 161
#  78 148 98 135 80 127 213 119 65 89 143 316 155 172 150 103 120 258 5 272
#  263 166 138 52 164 337 94 118 182 41 70 144 10 4 13 87 140 74 152 77 3 82
#  145 64 79 147 54 83 634 650 12 61 11 115 35 17 165 167 153 44 3.4 55 71
#  253 75 2.5 197 24 156 237 203 112 141 3.5 190 37 45 193 57 76 160 6 200
#  485 49 158 137 428 450 174 189 202 159 196 154 139 34 222 184 178 146 125
#  21 157 51 839 332 151 305 299 266 32 53 370 22 168 60 187 171 220 169 232
#  254 345 194 211 217 550 23 257 188 192 179 218 208 6.6 240]
# ----------------------------------------------------------------------------------------------------
# ['?' 128 116 76 83 133 105 122 48 90 79 104 88 107 126 113 150 93 157 80
# ...

# %%
numeric_col = thyro.select_dtypes(include=['number'])
data_range = numeric_col.describe().loc[['min', 'max']]

data_range
# Out:
#        Record ID   age
# min  840801013.0   1.0
# max  841031032.0  97.0

# %%
missing_values = thyro.isin(['?']).sum()
missing_values
# Out:
# Record ID                      0
# age                            0
# sex                           24
# on thyroxine                   0
# query on thyroxine             0
# on antithyroid medication      0
# sick                           0
# pregnant                       0
# thyroid surgery                0
# I131 treatment                 0
# query hypothyroid              0
# query hyperthyroid             0
# lithium                        0
# goitre                         0
# tumor                          0
# hypopituitary                  0
# psych                          0
# TSH measured                   0
# TSH                          115
# T3 measured                    0
# T3                           202
# TT4 measured                   0
# TT4                           40
# T4U measured                   0
# T4U                           98
# FTI measured                   0
# FTI                           98
# TBG measured                   0
# ...

# %%
outliers = {}
for col in numeric_col.columns:
    mean = numeric_col[col].mean()
    std = numeric_cols[col].std()
    lower_bound = mean - 3 * std
    upper_bound = mean + 3 * std
    outliers[col] = len(numeric_col[(numeric_col[col] < lower_bound) | (numeric_col[col] > upper_bound)])
    
display(outliers)
# Out:
# {'Record ID': 0, 'age': 0}

# %%
numeric_mean = numeric_col.mean()
numeric_variance = numeric_col.var()

print("Mean of Numeric data:       ",numeric_mean)
print("Variance of Numeric data :      ",numeric_variance)
# Out:
# Mean of Numeric data:        Record ID    8.409340e+08
# age          5.150900e+01
# dtype: float64
# Variance of Numeric data :       Record ID    5.819759e+09
# age          3.525585e+02
# dtype: float64

# %%
thyro['TSH'] = thyro['TSH'].replace('?', float('nan'))

thyro['TSH']
# Out:
# 0       0.3
# 1       1.6
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 995     0.1
# 996    53.0
# 997     NaN
# 998     0.1
# 999     3.3
# Name: TSH, Length: 1000, dtype: float64

# %%
column_mean = thyro['TSH'].mean()
column_mean
thyro['TSH'].fillna(column_mean, inplace=True)
thyro['TSH'] = thyro['TSH'].replace('?', float('nan'))
print(thyro["TSH"].isnull())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: TSH, Length: 1000, dtype: bool

# %%
import pandas as pd
import matplotlib.pyplot as plt


selected_columns = ['age','TSH','T3','TT4','T4U','FTI','TBG']


thyro[selected_columns].boxplot()

plt.title("Box Plots for Selected Columns")
plt.ylabel("Values")
plt.show()

# %%
thyro['T3'] = thyro['T3'].replace('?', float('nan'))
print(thyro["T3"])

column_mean = thyro['T3'].mean()
print(column_mean)

thyro['T3'].fillna(column_mean, inplace=True)

thyro['T3'] = thyro['T3'].replace('?', float('nan'))


thyro['FTI'] = thyro['FTI'].replace('?', float('nan'))
print(thyro["FTI"])

column_mean = thyro['FTI'].mean()
print(column_mean)

thyro['FTI'].fillna(column_mean, inplace=True)

thyro['FTI'] = thyro['FTI'].replace('?', float('nan'))


thyro['TT4'] = thyro['TT4'].replace('?', float('nan'))
print(thyro["TT4"])

column_mean = thyro['TT4'].mean()
print(column_mean)

thyro['TT4'].fillna(column_mean, inplace=True)

thyro['TT4'] = thyro['TT4'].replace('?', float('nan'))



thyro['T4U'] = thyro['T4U'].replace('?', float('nan'))
print(thyro["TT4"])

column_mean = thyro['T4U'].mean()
print(column_mean)

thyro['T4U'].fillna(column_mean, inplace=True)

thyro['T4U'] = thyro['T4U'].replace('?', float('nan'))



thyro['FTI'] = thyro['FTI'].replace('?', float('nan'))
print(thyro["FTI"])

column_mean = thyro['FTI'].mean()
print(column_mean)

thyro['FTI'].fillna(column_mean, inplace=True)

thyro['FTI'] = thyro['FTI'].replace('?', float('nan'))


thyro['TBG'] = thyro['TBG'].replace('?', float('nan'))
print(thyro["TBG"])

column_mean = thyro['TBG'].mean()
print(column_mean)

thyro['TBG'].fillna(column_mean, inplace=True)

thyro['TBG'] = thyro['TBG'].replace('?', float('nan'))
# Out:
# 0      1.822243
# 1      1.900000
# 2      1.822243
# 3      1.822243
# 4      1.822243
#          ...
# 995    2.100000
# 996    0.400000
# 997    1.822243
# 998    0.800000
# 999    1.200000
# Name: T3, Length: 1000, dtype: float64
# 1.8222431065162907
# 0      114.600887
# 1      114.600887
# 2      114.600887
# 3      114.600887
# 4      114.600887
#           ...
# 995    103.000000
# 996      6.600000
# 997    114.600887
# 998    240.000000
# 999     94.000000
# Name: FTI, Length: 1000, dtype: float64
# 114.60088691796008
# 0      106.447708
# 1      128.000000
# 2      106.447708
# 3      106.447708
# 4      106.447708
#           ...
# 995    148.000000
# 996      9.700000
# 997    106.447708
# 998    201.000000
# 999     85.000000
# Name: TT4, Length: 1000, dtype: float64
# 106.44770833333332
# 0      106.447708
# 1      128.000000
# 2      106.447708
# 3      106.447708
# 4      106.447708
#           ...
# 995    148.000000
# 996      9.700000
# 997    106.447708
# ...

# %%
thyro.to_excel('updated_dataset.xlsx', index=False)
upd=pd.read_excel("updated_dataset.xlsx")

upd
# Out:
#      Record ID  age sex on thyroxine query on thyroxine  \
# 0    840801013   29   F            f                  f
# 1    840801014   29   F            f                  f
# 2    840801042   41   F            f                  f
# 3    840803046   36   F            f                  f
# 4    840803047   32   F            f                  f
# ..         ...  ...  ..          ...                ...
# 995  841031002   41   F            f                  f
# 996  841031010   41   F            f                  f
# 997  841031030   20   F            f                  f
# 998  841031031   20   F            f                  f
# 999  841031032   73   F            f                  f
#
#     on antithyroid medication sick pregnant thyroid surgery I131 treatment  \
# 0                           f    f        f               f              f
# 1                           f    f        f               f              f
# ...

# %%
upd = upd.replace('?', np.nan)

columns_with_question_mark = upd.columns[upd.isna().any()].tolist()

print("Columns containing '?' (NaN) values:")
print(columns_with_question_mark)

upd.info()
# Out:
# Columns containing '?' (NaN) values:
# ['sex']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record ID                  1000 non-null   int64
#  1   age                        1000 non-null   int64
#  2   sex                        976 non-null    object
#  3   on thyroxine               1000 non-null   object
#  4   query on thyroxine         1000 non-null   object
#  5   on antithyroid medication  1000 non-null   object
#  6   sick                       1000 non-null   object
#  7   pregnant                   1000 non-null   object
#  8   thyroid surgery            1000 non-null   object
#  9   I131 treatment             1000 non-null   object
#  10  query hypothyroid          1000 non-null   object
#  11  query hyperthyroid         1000 non-null   object
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


selected_columns = ['age','TSH','T3','TT4','T4U','FTI','TBG']

upd[selected_columns].boxplot()

plt.title("Box Plots for Selected Columns")
plt.ylabel("Values")
plt.show()

# %%
mode_gender = thyro['sex'].mode()[0]
thyro['sex'].fillna(mode_gender, inplace=True)

thyro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record ID                  1000 non-null   int64
#  1   age                        1000 non-null   int64
#  2   sex                        1000 non-null   object
#  3   on thyroxine               1000 non-null   object
#  4   query on thyroxine         1000 non-null   object
#  5   on antithyroid medication  1000 non-null   object
#  6   sick                       1000 non-null   object
#  7   pregnant                   1000 non-null   object
#  8   thyroid surgery            1000 non-null   object
#  9   I131 treatment             1000 non-null   object
#  10  query hypothyroid          1000 non-null   object
#  11  query hyperthyroid         1000 non-null   object
#  12  lithium                    1000 non-null   object
# ...

# %%
z_threshold = 2.5

thyro_cleaned = thyro.copy()


for column in ['age', 'TSH', 'T3', 'TT4', 'T4U', 'FTI', 'TBG']:
 
    z_scores = np.abs((thyro_cleaned[column] - thyro_cleaned[column].mean()) / thyro_cleaned[column].std())

    outlier_rows = z_scores > z_threshold
    thyro_cleaned = thyro_cleaned[~outlier_rows]
    
thyro_cleaned
# Out:
#      Record ID       age sex on thyroxine query on thyroxine  \
# 0    840801013  0.165066   F            f                  f
# 1    840801014  0.165066   F            f                  f
# 2    840801042  0.207576   F            f                  f
# 3    840803046  0.192094   F            f                  f
# 4    840803047  0.177580   F            f                  f
# ..         ...       ...  ..          ...                ...
# 993  841030051  0.207576   M            f                  f
# 994  841030052  0.225630   M            f                  f
# 995  841031002  0.207576   F            f                  f
# 997  841031030  0.114287   F            f                  f
# 999  841031032  0.270288   F            f                  f
#
#     on antithyroid medication sick pregnant thyroid surgery I131 treatment  \
# 0                           f    f        f               f              f
# 1                           f    f        f               f              f
# ...

# %%
thyro_cleaned[selected_columns].boxplot()

plt.title("Box Plots for Selected Columns")
plt.ylabel("Values")
plt.show()

# %%
binary_attributes = ['on thyroxine', 'query on thyroxine', 'on antithyroid medication',
                     'sick', 'pregnant', 'thyroid surgery', 'I131 treatment', 'query hypothyroid',
                     'query hyperthyroid', 'lithium', 'goitre', 'tumor', 'hypopituitary']

vector1 = thyro.loc[0, binary_attributes].astype(str)
vector2 = thyro.loc[1, binary_attributes].astype(str)
f11 = sum((vector1 == '1') & (vector2 == '1'))
f01 = sum((vector1 == '0') & (vector2 == '1'))
f10 = sum((vector1 == '1') & (vector2 == '0'))
f00 = sum((vector1 == '0') & (vector2 == '0'))

if f01 + f10 + f11 != 0:
    jc = f11 / (f01 + f10 + f11)
else:
    jc = 0.0  
if f00 + f01 + f10 + f11 != 0:
    smc = (f11 + f00) / (f00 + f01 + f10 + f11)
else:
    smc = 0.0  

print("Jaccard Coefficient (JC):", jc)
print("Simple Matching Coefficient (SMC):", smc)
# Out:
# Jaccard Coefficient (JC): 0.0
# Simple Matching Coefficient (SMC): 0.0

# %%
import pandas as pd
import numpy as np
selected_columns = ['age','TSH','T3','TT4','T4U','FTI','TBG'] 
for column in selected_columns:
    upd[column] = np.log10(upd[column])

# %%
upd[selected_columns].boxplot()
plt.title("Box Plots for Selected Columns")
plt.ylabel("Values")
plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity
vector1 = thyro.iloc[0, 1:].apply(lambda x: float(x) if str(x).replace('.', '', 1).isdigit() else np.nan)
vector2 = thyro.iloc[1, 1:].apply(lambda x: float(x) if str(x).replace('.', '', 1).isdigit() else np.nan)
dot_product = np.dot(vector1, vector2)
magnitude_vector1 = np.linalg.norm(vector1)
magnitude_vector2 = np.linalg.norm(vector2)
cosine_similarity = dot_product / (magnitude_vector1 * magnitude_vector2)
print("Cosine Similarity:", cosine_similarity)
# Out:
# Cosine Similarity: nan

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import jaccard_score
from sklearn.metrics.pairwise import cosine_similarity

vectors = thyro.iloc[:15, 1:-1] 
def jaccard_coefficient(vector1, vector2):
    intersection = np.logical_and(vector1, vector2)
    union = np.logical_or(vector1, vector2)
    return np.sum(intersection) / np.sum(union)
jc_matrix = np.zeros((15, 15))
smc_matrix = np.zeros((15, 15))
cosine_matrix = np.zeros((15, 15))
for i in range(15):
    for j in range(15):
        vector1 = vectors.iloc[i].astype(bool)
        vector2 = vectors.iloc[j].astype(bool)
        jc_matrix[i, j] = jaccard_coefficient(vector1, vector2)
        smc_matrix[i, j] = jaccard_score(vector1, vector2, average='binary')
        cosine_matrix[i, j] = cosine_similarity([vector1], [vector2])[0, 0]
plt.figure(figsize=(10, 8))
sns.heatmap(jc_matrix, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=False, yticklabels=False)
plt.title("Jaccard Coefficient Heatmap")
plt.show()
plt.figure(figsize=(10, 8))
sns.heatmap(smc_matrix, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=False, yticklabels=False)
plt.title("Simple Matching Coefficient Heatmap")
plt.show()
plt.figure(figsize=(10, 8))
sns.heatmap(cosine_matrix, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=False, yticklabels=False)
plt.title("Cosine Similarity Heatmap")
plt.show()
